# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/power_information_detail.csv')
df
# Out:
#            日期  淨尖峰供電能力(MW)  尖峰負載(MW)  備轉容量(MW)  備轉容量率(%)  工業用電(百萬度)  \
# 0    20210101        28487     25720      2767     10.76    311.468
# 1    20210102        28421     25485      2936     11.52    304.952
# 2    20210103        28513     25476      3037     11.92    299.771
# 3    20210104        32766     29734      3032     10.20    342.273
# 4    20210105        33117     30050      3067     10.21    353.795
# ..        ...          ...       ...       ...       ...        ...
# 419  20220224        33609     31098      2511      8.07    371.852
# 420  20220225        33527     30121      3406     11.31    365.893
# 421  20220226        31259     27822      3437     12.35    342.340
# 422  20220227        29926     26196      3730     14.24    317.200
# 423  20220228        31464     27337      4127     15.10    323.679
#
#      民生用電(百萬度)  核一#1(萬瓩)  核一#2(萬瓩)  核二#1(萬瓩)  ...   大觀二    明潭   碧海   立霧   龍澗  \
# ...

# %%
mv = df['備轉容量(MW)']
date = pd.to_datetime(df['日期'],format='%Y%m%d')
plt.plot(date,mv)

# %%
mv.describe()
# Out:
# count     424.000000
# mean     3612.856132
# std       906.625756
# min      1437.000000
# 25%      3032.750000
# 50%      3307.500000
# 75%      4007.250000
# max      6911.000000
# Name: 備轉容量(MW), dtype: float64

# %%
df2 = pd.read_csv('data/近三年每日尖峰備轉容量率.csv')

mv = df2['備轉容量(萬瓩)']
date = pd.to_datetime(df2['日期'],format='%Y/%m/%d')
plt.plot(date,mv)
